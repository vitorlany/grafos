# %% [markdown]
# <a href="https://colab.research.google.com/github/vitorlany/grafos/blob/main/GrafoTeste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import urllib.request

# %%
url = "https://pucminas.instructure.com/courses/148628/files/7937949/download?download_frd=1"

# %%
graph = nx.Graph()

with urllib.request.urlopen(url) as f:
    for line in f:
        u, v = map(int, line.strip().split())
        graph.add_edge(u, v)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-629a62440904> in <module>
#       3 with urllib.request.urlopen(url) as f:
#       4     for line in f:
# ----> 5         u, v = map(int, line.strip().split())
#       6         graph.add_edge(u, v)
#
# ValueError: invalid literal for int() with base 10: b'<!DOCTYPE'

# %%
nx.draw(graph, with_labels=True)
